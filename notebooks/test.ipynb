# %%
from datetime import datetime

import nfl_data_py as nfl
import sys
import os
module_path = os.path.abspath(os.path.join('../..'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
import src.data.weekly.collect as collect_weekly

# %%
# All years 1999 and later
current_year = datetime.now().year
years = list(range(1999, current_year + 1))
weekly_df = collect_weekly.get_weekly_data([2023])
weekly_df.sort_values(by=['opponent_team', 'week'])
# Out:
# Downcasting floats.
#     team  season  week season_type opponent_team  completions  attempts  \
# 553  WAS    2023     1         REG           ARI           19        31
# 411  NYG    2023     2         REG           ARI           26        37
# 143  DAL    2023     3         REG           ARI           25        40
# 500   SF    2023     4         REG           ARI           20        21
# 110  CIN    2023     5         REG           ARI           36        46
# ..   ...     ...   ...         ...           ...          ...       ...
# 352  MIA    2023    13         REG           WAS           19        25
# 302   LA    2023    15         REG           WAS           25        33
# 441  NYJ    2023    16         REG           WAS           27        49
# 512   SF    2023    17         REG           WAS           22        28
# 157  DAL    2023    18         REG           WAS           34        40
#
#      passing_yards  passing_tds  interceptions  ...  \
# ...

# %%
# are targets ever different from receptions?
weekly_df[weekly_df['pacr'] != weekly_df['racr']]
# Out:
#     team  season  week season_type opponent_team  completions  attempts  \
# 0    ARI    2023     1         REG           WAS           21        30
# 1    ARI    2023     2         REG           NYG           21        31
# 2    ARI    2023     3         REG           DAL           17        21
# 3    ARI    2023     4         REG            SF           28        41
# 4    ARI    2023     5         REG           CIN           15        32
# ..   ...     ...   ...         ...           ...          ...       ...
# 565  WAS    2023    13         REG           MIA           12        23
# 566  WAS    2023    15         REG            LA           19        36
# 567  WAS    2023    16         REG           NYJ           16        35
# 568  WAS    2023    17         REG            SF           17        28
# 569  WAS    2023    18         REG           DAL           20        28
#
#      passing_yards  passing_tds  interceptions  ...  \
# ...

# %%
nfl.see_weekly_cols()
# Out:
# Index(['player_id', 'player_name', 'player_display_name', 'position',
#        'position_group', 'headshot_url', 'recent_team', 'season', 'week',
#        'season_type', 'opponent_team', 'completions', 'attempts',
#        'passing_yards', 'passing_tds', 'interceptions', 'sacks', 'sack_yards',
#        'sack_fumbles', 'sack_fumbles_lost', 'passing_air_yards',
#        'passing_yards_after_catch', 'passing_first_downs', 'passing_epa',
#        'passing_2pt_conversions', 'pacr', 'dakota', 'carries', 'rushing_yards',
#        'rushing_tds', 'rushing_fumbles', 'rushing_fumbles_lost',
#        'rushing_first_downs', 'rushing_epa', 'rushing_2pt_conversions',
#        'receptions', 'targets', 'receiving_yards', 'receiving_tds',
#        'receiving_fumbles', 'receiving_fumbles_lost', 'receiving_air_yards',
#        'receiving_yards_after_catch', 'receiving_first_downs', 'receiving_epa',
#        'receiving_2pt_conversions', 'racr', 'target_share', 'air_yards_share',
# ...

# %%
nfl.import_schedules([2023])
# Out:
#               game_id  season game_type  week     gameday   weekday gametime  \
# 6421   2023_01_DET_KC    2023       REG     1  2023-09-07  Thursday    20:20
# 6422  2023_01_CAR_ATL    2023       REG     1  2023-09-10    Sunday    13:00
# 6423  2023_01_HOU_BAL    2023       REG     1  2023-09-10    Sunday    13:00
# 6424  2023_01_CIN_CLE    2023       REG     1  2023-09-10    Sunday    13:00
# 6425  2023_01_JAX_IND    2023       REG     1  2023-09-10    Sunday    13:00
# ...               ...     ...       ...   ...         ...       ...      ...
# 6701   2023_20_TB_DET    2023       DIV    20  2024-01-21    Sunday    15:00
# 6702   2023_20_KC_BUF    2023       DIV    20  2024-01-21    Sunday    18:30
# 6703   2023_21_KC_BAL    2023       CON    21  2024-01-28    Sunday    15:00
# 6704   2023_21_DET_SF    2023       CON    21  2024-01-28    Sunday    18:30
# 6705    2023_22_SF_KC    2023        SB    22  2024-02-11    Sunday    18:30
#
# ...
