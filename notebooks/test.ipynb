# %%
import os
import sys

module_path = os.path.abspath(os.path.join('..'))
print(module_path)
if module_path not in sys.path:
    sys.path.append(module_path)
    
from src.data.collect_all import get_schedule_and_weekly_data
# Out:
# C:\Users\joshu\nfl-predictions

# %%
# get every number from 1999 to 2021
years = range(1999, 2022)
# Out:
# [1999,
#  2000,
#  2001,
#  2002,
#  2003,
#  2004,
#  2005,
#  2006,
#  2007,
#  2008,
#  2009,
#  2010,
#  2011,
#  2012,
#  2013,
#  2014,
#  2015,
#  2016,
#  2017,
#  2018,
#  2019,
#  2020,
#  2021]

# %%
df = get_schedule_and_weekly_data(list(range(1999, 2022)))
# Out:
# Downcasting floats.
# Downcasting floats.
# Downcasting floats.
# Downcasting floats.
# Downcasting floats.
# Downcasting floats.
# Downcasting floats.
# Downcasting floats.
# Downcasting floats.
# Downcasting floats.
# Downcasting floats.
# Downcasting floats.
# Downcasting floats.
# Downcasting floats.
# Downcasting floats.
# Downcasting floats.
# Downcasting floats.
# Downcasting floats.
# Downcasting floats.
# Downcasting floats.
# Downcasting floats.
# Downcasting floats.
# Downcasting floats.

# %%
df
# Out:
#                game_id  season game_type  week opp_team  opp_score  \
# 0      1999_01_MIN_ATL    1999       REG     1      MIN       17.0
# 1       1999_01_KC_CHI    1999       REG     1       KC       17.0
# 2      1999_01_PIT_CLE    1999       REG     1      PIT       43.0
# 3      1999_01_BUF_IND    1999       REG     1      BUF       14.0
# 4       1999_01_SF_JAX    1999       REG     1       SF        3.0
# ...                ...     ...       ...   ...      ...        ...
# 10509    2021_20_LA_TB    2021       DIV    20       TB       27.0
# 10510   2021_20_BUF_KC    2021       DIV    20       KC       42.0
# 10511   2021_21_CIN_KC    2021       CON    21       KC       24.0
# 10512    2021_21_SF_LA    2021       CON    21       LA       20.0
# 10513   2021_22_LA_CIN    2021        SB    22      CIN       20.0
#
#       target_team  target_score  div_game  target_days_since_previous_game  \
# 0             ATL          14.0         0                            240.0
# ...

# %%
df[df['game_id'] == '2000_01_SF_ATL']
# Out:
#              game_id  season game_type  week opp_team  opp_score target_team  \
# 210   2000_01_SF_ATL    2000       REG     1       SF       28.0         ATL
# 5467  2000_01_SF_ATL    2000       REG     1      ATL       36.0          SF
#
#       target_score  div_game  target_days_since_previous_game  ...  \
# 210           36.0         1                            240.0  ...
# 5467          28.0         1                            240.0  ...
#
#       def_target_racr  def_target_racr_cumulative_average  \
# 210               0.0                                 0.0
# 5467              0.0                                 0.0
#
#       def_target_racr_cumulative_average_change  def_target_wopr  \
# 210                                         0.0              0.0
# 5467                                        0.0              0.0
#
#       def_target_wopr_cumulative_average  \
# 210                                  0.0
# 5467                                 0.0
#
# ...

# %%
df[(df['target_team'] == 'ARI') & (df['week'].isin([17, 1, 2])) & df['season'].isin([2000, 2001])]
# Out:
#               game_id  season game_type  week opp_team  opp_score target_team  \
# 233   2000_02_DAL_ARI    2000       REG     2      DAL       31.0         ARI
# 441   2001_02_DEN_ARI    2001       REG     2      DEN       38.0         ARI
# 5473  2000_01_ARI_NYG    2000       REG     1      NYG       21.0         ARI
# 5666  2000_17_ARI_WAS    2000       REG    17      WAS       20.0         ARI
# 5874  2001_17_ARI_WAS    2001       REG    17      WAS       20.0         ARI
#
#       target_score  div_game  target_days_since_previous_game  ...  \
# 233           32.0         1                              7.0  ...
# 441           17.0         0                              NaN  ...
# 5473          16.0         1                            240.0  ...
# 5666           3.0         1                              7.0  ...
# 5874          17.0         1                              7.0  ...
#
#       def_target_racr  def_target_racr_cumulative_average  \
# ...
